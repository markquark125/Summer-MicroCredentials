# %% [markdown]
# <a href="https://colab.research.google.com/github/markquark125/Summer-MicroCredentials/blob/main/Matplotlib_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Exercises
#
# MatPlotLib Review!
#
# Take your time, Matplotlib can be tricky to understand at first.
#
# These should be relatively simple plots, however they can be hard if this is your first time with matplotlib, please feel free to reference the site documentation as you go along.
#
# # Exercises
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
# .arrange returns evenly spaced values within a given interval.
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Not sure what %matplotlib inline does but found this: https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline

#!pip install matplotlib

# %% [markdown]
# ## Exercise 1
#
# * **Create a figure object called fig using plt.figure() **
# * **Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * **Plot (x,y) on that axes and set the labels and titles to match the plot below: **

# %%
fig = plt.figure()


ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, y, 'b',linewidth=1)
ax.set_xlabel("y") 
ax.set_ylabel('x')
ax.set_title("title")

ax.set_xlim([0, 100])
ax.set_ylim([0, 200])


ax.set_xticks([0,20,40,60,80,100])
ax.set_yticks([0,50,100,150,200]);

# %%
# space

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

ax2.set_xticks([0,0.2,0.4,0.6,0.8,1])
ax2.set_yticks([0,0.2,0.4,0.6,0.8,1]);

# %%
# space

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
# The larger figure: ax1
ax1.plot(x, y, 'r', linewidth=0.5)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
#ax1.set_title('Axes 1 Title')

# The smaller figure: ax2
ax2.plot(x,y, 'r', linewidth=0.5)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
#ax2.set_title('Axes 2 Title')

ax1.set_xlim([0, 100])
ax1.set_ylim([0, 200])

ax2.set_xlim([0, 100])
ax2.set_ylim([0, 200])

ax1.set_yticks([0,50,100,150,200])
ax2.set_xticks([0,20,40,60,80,100])
ax2.set_yticks([0,50,100,150,200])


fig

# %%
# space

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

# %%
|# space

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
ax1.plot(x,z, 'b', linewidth=1)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')


ax2.plot(x,y, 'b', linewidth=1)
ax2.set_ylabel('Y')
ax2.set_xlabel('X')
ax2.set_title('zoom')
ax2.set_xlim(20,22)
ax2.set_ylim(30, 50)

ax1.set_xlim([0, 100])
ax1.set_ylim([0, 10000])

ax2.set_xlim([20, 22.0])
ax2.set_ylim([30,50])

'''
ax1.set_yticks([0,50,100,150,200])
'''
ax2.set_yticks([30,35,40,45,50])
ax2.set_xticks([20,20.5,21.0,21.5,22.0])

fig

# could not figure out how to display fig twice, tho.

# %%
# space

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
plt1 = plt.subplot(1,2,1)
plt.plot(x,y,'b--', linewidth=3)
plt2 = plt.subplot(1,2,2)
plt.plot(x,z,'r', linewidth=3);

plt1.set_xlim([0, 100])
plt1.set_ylim([0, 200])
plt1.set_yticks([0,50,100,150,200])

plt2.set_xlim([0, 100])
plt2.set_ylim([0, 10000])

#plt.tight_layout()
# Out:
# (0.0, 10000.0)

# %% [markdown]
# *See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 2))

plt1 = plt.subplot(1,2,1)#.set_ylim(0,200)
plt.plot(x,y,'b', linewidth=4)
plt2 = plt.subplot(1,2,2)#.set_ylim(0, 100)
plt.plot(y,z,'r--', linewidth=2);

plt1.set_xlim([0, 100])
plt1.set_ylim([0, 200])
plt1.set_ylabel('y')

plt2.set_xlim([0, 100])
plt2.set_ylim([0, 10000])
# Out:
# (0.0, 10000.0)

# %% [markdown]
# # Cheers!
